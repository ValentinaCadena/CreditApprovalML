# %% [markdown]
# # Sistema de Predicción de Aprobación de Tarjetas de Crédito usando Aprendizaje Automático

# %% [markdown]
# - Valentina C. Zapata - valentina.candenaz@udea.edu.co
# - Luis G. Sánchez - valentina.candenaz@udea.edu.co
# - Jose D. Gómez Muñetón. - valentina.candenaz@udea.edu.co

# %% [markdown]
# >Palabras Clave — Modelos predictivos, Árboles de decisión, Regresión logística, Riesgo crediticio, Aprendizaje supervisado.

# %% [markdown]
# ## 1. Introducción

# %% [markdown]
# En elpresente proyecto se propone desarrollar un modelo de aprendizaje automático (Machine Learning) capaz de predecir si un solicitante será un “buen” o “mal” cliente. Este enfoque busca automatizar y optimizar el proceso de aprobación de tarjetas de crédito, permitiendo al banco reducir riesgos y mejorar la eficiencia del proceso de evaluación. La solución basada en Machine Learning permitirá no solo realizar predicciones, sino también adaptarse mejor a nuevas condiciones económicas o cambios en los patrones de comportamiento de los usuarios.

# %% [markdown]
# ## 2. Descripción del Problema

# %% [markdown]
# La aprobación de tarjetas de crédito es un proceso crítico para las entidades financieras, ya que implica una evaluación cuidadosa del riesgo crediticio asociado a cada solicitante. Con el objetivo de mitigar el riesgo de impago, los bancos utilizan modelos predictivos basados en información personal, laboral y financiera de los solicitantes para decidir si aprueban o no una solicitud. Tradicionalmente, esta evaluación se realiza a través de puntuaciones crediticias construidas a partir de modelos estadísticos como la regresión logística.
#
# El desarrollo de una solución basada en Machine Learning ofrece ventajas significativas sobre los métodos tradicionales, ya que estos modelos pueden captar patrones complejos y no lineales en los datos que los enfoques estadísticos conven cionales podrían pasar por alto. Además, los algoritmos de Machine Learning tienen la capacidad de aprender y mejorar con el tiempo a medida que se dispone de nuevos datos, lo que permite una adaptación dinámica a cambios en el comportamiento de los solicitantes o en las características del perfil de los clientes objetivo.
#
# El conjunto de datos utilizado proviene del portal Kaggle [1] y se compone de dos archivos principales: application record.csv y credit record.csv. El primero contiene información detallada sobre los solicitantes, incluyendo datos demográficos, laborales y financieros, mientras que el segundo recoge el comportamiento crediticio a lo largo del tiempo.
#
# La información demográfica proporciona datos clave sobre el perfil del solicitante y permite comprender aspectos sociales y personales que pueden influir en el comportamiento crediticio a lo largo del tiempo. Por otra parte, se incluyen también variables de carácter económico y laboral, como el nivel de ingresos, el tipo de empleo, el nivel educativo y la ocupación, que ayudan a estimar la estabilidad financiera del solicitante y su capacidad para generar ingresos de manera sostenida.
#
# Asimismo, se consideran datos sobre propiedades y activos, tales como la posesión de vivienda, automóvil y número de miembros dependientes, los cuales permiten evaluar el patrimonio y las responsabilidades económicas del solicitante. Finalmente, el historial crediticio, registrado en credit record.csv, proporciona una visión temporal del comportamiento de pago, incluyendo retrasos y cumplimiento de pagos.
#
# En conjunto, estas variables reflejan la solvencia económica del solicitante, lo cual es fundamental para evaluar su capacidad de pago y, por ende, el riesgo crediticio asociado a la aprobación de una tarjeta de crédito.
#
# En total, se cuenta con 438,557 registros de información de clientes, descritos mediante 17 variables, y 1,048,575 registros en el historial de créditos. Las variables son de tipo categórico, numérico y binario. Entre las variables categóricas se incluyen el género, tipo de ingreso, nivel educativo, estado civil, tipo de vivienda y ocupación; las variables numéricas abarcan el número de hijos, ingresos totales, edad y años trabajados; mientras que las variables binarias indican características como si el solicitante posee coche o vivienda.
#
# Durante el análisis exploratorio se identificaron valores faltantes en la variable OCCUPATION TYPE (ocupación). Por ello, se propone imputar dicha variable con la categoría “Desconocido”. Adicionalmente, se sugiere contrastar estos datos con la variable de días de desempleo, con el fin de imputar los valores faltantes como “Desempleado” en aquellos casos donde se registre un periodo de desempleo.
#
# En cuanto a la codificación de variables, se aplicará codificación ordinal para aquellas que presenten una jerarquía inherente, como el nivel educativo, y codificación one-hot para el resto de las variables categóricas. Asimismo, se llevará a cabo escalamiento o normalización en las variables numéricas que lo requieran, como AMT INCOME TOTAL (ingresos anuales), con el objetivo de mejorar el rendimiento de los modelos.
#
# Un reto importante de este dataset es la ausencia de una etiqueta explícita que indique si la solicitud fue aprobada o si el cliente fue bueno o malo. Por lo tanto, se debe construir una variable objetivo a partir de la información contenida en credit record.csv. Una alternativa es etiquetar como “buen cliente” a aquel que no presenta atrasos significativos (por ejemplo, no más de dos meses de mora en los pagos), y como “mal cliente” a aquellos con historial negativo recurrente.
#
# El problema a resolver es de clasificación binaria, y se evaluarán diferentes modelos del aprendizaje automático. En primer lugar, se considerará la regresión logística debido a su facilidad de interpretación y su uso frecuente en el ámbito f inanciero. No obstante, este modelo puede no ser suficiente si las relaciones entre variables no son lineales. En ese caso, se recurrirá a modelos de árboles de decisión, como el Random Forest, que son más robustos frente a datos mixtos y no requieren un extenso preprocesamiento. Finalmente, se tendrá en cuenta el uso de modelos de gradiente como XGBoost, ampliamente reconocidos por su precisión en competencias y aplicaciones reales, aunque más complejos en su ajuste y explicación. La comparación entre estos modelos permitirá seleccionar aquel que logre el mejor balance entre precisión, interpretabilidad y eficiencia.
#
# Es importante tener en cuenta el desbalance de clases que se puede presentar al construir la variable objetivo. Este fenómeno puede llevar a que los modelos predicen más frecuentemente la clase mayoritaria, afectando su desempeño real. Para mitigarlo, se planea aplicar técnicas como la reponderación de clases, el sobremuestreo de la clase minoritaria mediante métodos como SMOTE, o la utilización de métricas como el F1-score o el AUC-ROC, más adecuadas en escenarios desbalanceados.

# %% [markdown]
# > Nota: Recuerda que para ejecutar este código debes tener instaladas las librerías necesarias. Puedes instalar las librerías que no tengas con el comando `pip install -r requirements.txt`.

# %%
# Manipulación de datos
import pandas as pd
import numpy as np
from os.path import join

# Visualización
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocesamiento y ML
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC


from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    roc_auc_score,
    roc_curve
)

# Técnicas de balanceo de clases
from imblearn.over_sampling import SMOTE

# Selección de características
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.decomposition import PCA

# %% [markdown]
# ### 2.1 Análisis del Conjunto de Datos

# %%
data_folder = 'data'
application_df = pd.read_csv(join(data_folder, 'application_record.csv'))
credit_record_df = pd.read_csv(join(data_folder, 'credit_record.csv'))

# %%
application_df.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
credit_record_df.head()
# Out:
#         ID  MONTHS_BALANCE STATUS
# 0  5001711               0      X
# 1  5001711              -1      0
# 2  5001711              -2      0
# 3  5001711              -3      0
# 4  5001712               0      C

# %% [markdown]
# #### 2.1.1 Tamaño del Conjunto de Datos

# %%
application_df.shape, credit_record_df.shape
# Out:
# ((438557, 18), (1048575, 3))

# %% [markdown]
# #### 2.1.2 Variables del Conjunto de Datos

# %%
application_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438557 entries, 0 to 438556
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   438557 non-null  int64
#  1   CODE_GENDER          438557 non-null  object
#  2   FLAG_OWN_CAR         438557 non-null  object
#  3   FLAG_OWN_REALTY      438557 non-null  object
#  4   CNT_CHILDREN         438557 non-null  int64
#  5   AMT_INCOME_TOTAL     438557 non-null  float64
#  6   NAME_INCOME_TYPE     438557 non-null  object
#  7   NAME_EDUCATION_TYPE  438557 non-null  object
#  8   NAME_FAMILY_STATUS   438557 non-null  object
#  9   NAME_HOUSING_TYPE    438557 non-null  object
#  10  DAYS_BIRTH           438557 non-null  int64
#  11  DAYS_EMPLOYED        438557 non-null  int64
#  12  FLAG_MOBIL           438557 non-null  int64
#  13  FLAG_WORK_PHONE      438557 non-null  int64
#  14  FLAG_PHONE           438557 non-null  int64
# ...

# %%
application_df.describe()
# Out:
#                  ID   CNT_CHILDREN  AMT_INCOME_TOTAL     DAYS_BIRTH  \
# count  4.385570e+05  438557.000000      4.385570e+05  438557.000000
# mean   6.022176e+06       0.427390      1.875243e+05  -15997.904649
# std    5.716370e+05       0.724882      1.100869e+05    4185.030007
# min    5.008804e+06       0.000000      2.610000e+04  -25201.000000
# 25%    5.609375e+06       0.000000      1.215000e+05  -19483.000000
# 50%    6.047745e+06       0.000000      1.607805e+05  -15630.000000
# 75%    6.456971e+06       1.000000      2.250000e+05  -12514.000000
# max    7.999952e+06      19.000000      6.750000e+06   -7489.000000
#
#        DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE     FLAG_PHONE  \
# count  438557.000000    438557.0    438557.000000  438557.000000
# mean    60563.675328         1.0         0.206133       0.287771
# std    138767.799647         0.0         0.404527       0.452724
# min    -17531.000000         1.0         0.000000       0.000000
# ...

# %%
# Encontrar los posibles valores que se usan en las columnas categóricas
for col in application_df.select_dtypes(include=['object']).columns:
    print(f'{col}: {application_df[col].unique()}')
# Out:
# CODE_GENDER: ['M' 'F']
# FLAG_OWN_CAR: ['Y' 'N']
# FLAG_OWN_REALTY: ['Y' 'N']
# NAME_INCOME_TYPE: ['Working' 'Commercial associate' 'Pensioner' 'State servant' 'Student']
# NAME_EDUCATION_TYPE: ['Higher education' 'Secondary / secondary special' 'Incomplete higher'
#  'Lower secondary' 'Academic degree']
# NAME_FAMILY_STATUS: ['Civil marriage' 'Married' 'Single / not married' 'Separated' 'Widow']
# NAME_HOUSING_TYPE: ['Rented apartment' 'House / apartment' 'Municipal apartment'
#  'With parents' 'Co-op apartment' 'Office apartment']
# OCCUPATION_TYPE: [nan 'Security staff' 'Sales staff' 'Accountants' 'Laborers' 'Managers'
#  'Drivers' 'Core staff' 'High skill tech staff' 'Cleaning staff'
#  'Private service staff' 'Cooking staff' 'Low-skill Laborers'
#  'Medicine staff' 'Secretaries' 'Waiters/barmen staff' 'HR staff'
#  'Realty agents' 'IT staff']

# %% [markdown]
# - **CODE_GENDER**
#   - M: Masculino
#   - F: Femenino
#
# - **FLAG_OWN_CAR**
#   - Y: Propietario de un coche
#   - N: No propietario de un coche
#
# - **FLAG_OWN_REALTY**
#   - Y: Propietario de una propiedad
#   - N: No propietario de una propiedad
#
# - **NAME_INCOME_TYPE**
#   - Working: Trabajador
#   - Commercial associate: Asociado comercial
#   - State servant: Servidor público
#   - Pensioner: Jubilado
#   - Student: Estudiante
#
# - **NAME_EDUCATION_TYPE**
#   - Higher education: Educación superior
#   - Secondary / secondary special: Secundaria / secundaria especial
#   - Incomplete higher: Educación superior incompleta
#   - Lower secondary: Secundaria inferior
#   - Academic degree: Grado académico
#
# - **NAME_FAMILY_STATUS**
#   - Married: Casado
#   - Single / not married: Soltero / no casado
#   - Civil marriage: Matrimonio civil
#   - Widow: Viudo
#   - Separated: Separado
#
# - **NAME_HOUSING_TYPE**
#   - House / apartment: Casa / apartamento
#   - With parents: Con padres
#   - Co-op apartment: Apartamento cooperativo
#   - Rented apartment: Apartamento alquilado
#   - Municipal apartment: Apartamento municipal
#   - Office apartment: Apartamento de oficina
#
# - **OCCUPATION_TYPE**
#   - [Empty]: Ocupación vacía
#   - Laborers: Trabajadores
#   - Sales staff: Personal de ventas
#   - Managers: Gerentes
#   - Drivers: Conductores
#   - High skill tech staff: Personal técnico altamente cualificado
#   - Accountants: Contadores
#   - Medicine staff: Personal médico
#   - Security staff: Personal de seguridad
#   - Cleaning staff: Personal de limpieza
#   - Cooking staff: Personal de cocina
#   - Waiters/barmen staff: Personal de servicio de mesa/barra
#   - Low-skill Laborers: Trabajadores no cualificados
#   - Core staff: Personal básico
#   - Private service staff: Personal de servicio privado
#   - Secretaries: Secretarias
#   - HR staff: Personal de recursos humanos
#   - Reality agents: Agentes inmobiliarios
#   - IT staff: Personal de TI

# %%
application_df.OCCUPATION_TYPE.value_counts()
# Out:
# OCCUPATION_TYPE
# Laborers                 78240
# Core staff               43007
# Sales staff              41098
# Managers                 35487
# Drivers                  26090
# High skill tech staff    17289
# Accountants              15985
# Medicine staff           13520
# Cooking staff             8076
# Security staff            7993
# Cleaning staff            5845
# Private service staff     3456
# Low-skill Laborers        2140
# Secretaries               2044
# Waiters/barmen staff      1665
# Realty agents             1041
# HR staff                   774
# IT staff                   604
# Name: count, dtype: int64

# %%
credit_record_df.describe()
# Out:
#                  ID  MONTHS_BALANCE
# count  1.048575e+06    1.048575e+06
# mean   5.068286e+06   -1.913700e+01
# std    4.615058e+04    1.402350e+01
# min    5.001711e+06   -6.000000e+01
# 25%    5.023644e+06   -2.900000e+01
# 50%    5.062104e+06   -1.700000e+01
# 75%    5.113856e+06   -7.000000e+00
# max    5.150487e+06    0.000000e+00

# %%
# Encontrar los posibles valores que se usan en las columnas categóricas
for col in credit_record_df.select_dtypes(include=['object']).columns:
    print(f'{col}: {credit_record_df[col].unique()}')
# Out:
# STATUS: ['X' '0' 'C' '1' '2' '3' '4' '5']

# %% [markdown]
# - **STATUS**
#   - 0: 1-29 días de retraso
#   - 1: 30-59 días de retraso
#   - 2: 60-89 días de retraso
#   - 3: 90-119 días de retraso
#   - 4: 120-149 días de retraso
#   - 5: Retraso o deudas incobrables, cancelaciones por más de 150 días
#   - C: Pagado este mes
#   - X: Sin préstamo para el mes

# %%
application_df.hist()
# Out:
# array([[<Axes: title={'center': 'ID'}>,
#         <Axes: title={'center': 'CNT_CHILDREN'}>,
#         <Axes: title={'center': 'AMT_INCOME_TOTAL'}>],
#        [<Axes: title={'center': 'DAYS_BIRTH'}>,
#         <Axes: title={'center': 'DAYS_EMPLOYED'}>,
#         <Axes: title={'center': 'FLAG_MOBIL'}>],
#        [<Axes: title={'center': 'FLAG_WORK_PHONE'}>,
#         <Axes: title={'center': 'FLAG_PHONE'}>,
#         <Axes: title={'center': 'FLAG_EMAIL'}>],
#        [<Axes: title={'center': 'CNT_FAM_MEMBERS'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ### 2.2 Imputación de Datos Faltantes y Eliminación de Duplicados

# %%
# Mostrar el número de valores nulos en cada columna
application_df.isna().sum()
# Out:
# ID                          0
# CODE_GENDER                 0
# FLAG_OWN_CAR                0
# FLAG_OWN_REALTY             0
# CNT_CHILDREN                0
# AMT_INCOME_TOTAL            0
# NAME_INCOME_TYPE            0
# NAME_EDUCATION_TYPE         0
# NAME_FAMILY_STATUS          0
# NAME_HOUSING_TYPE           0
# DAYS_BIRTH                  0
# DAYS_EMPLOYED               0
# FLAG_MOBIL                  0
# FLAG_WORK_PHONE             0
# FLAG_PHONE                  0
# FLAG_EMAIL                  0
# OCCUPATION_TYPE        134203
# CNT_FAM_MEMBERS             0
# dtype: int64

# %% [markdown]
# Como se puede ver en la columna OCCUPATION_TYPE, hay muchos valores nulos, y es la única columna que tiene valores nulos, y debido al contexto del dataset, podemos asumir que los valores nulos son personas que no tienen un trabajo definido, por lo que podemos reemplazar los valores nulos con 'Desconocido'. Además que resulta díficil imputar los valores nulos con la ocupación de la persona, ya que no tenemos información suficiente para hacerlo. Por lo tanto, se opta por reemplazar los valores nulos con 'Desconocido'.

# %%
# Reemplazar los valores nulos en OCCUPATION_TYPE con 'Desconocido'
application_df['OCCUPATION_TYPE'] = application_df['OCCUPATION_TYPE'].fillna('Desconocido')

# %% [markdown]
# Algunos registros en el dataset de aplicantes tienen más de un registro, lo que indica que el solicitante ha solicitado una tarjeta de crédito más de una vez. Para evitar duplicados, se eliminarán los registros duplicados basándose en el identificador único del solicitante (ID).

# %%
application_df = application_df.drop_duplicates(subset='ID', keep='first')

# %% [markdown]
# Además se evaluará si hay clases con valores constantes, es decir, si hay clases que tienen el mismo valor en todas las filas. Si se encuentra alguna clase con valores constantes, se eliminará esa columna del dataset, ya que no aporta información relevante para el modelo.

# %%
# Evaluación de clases con valores constantes
for col in application_df.columns:
    if application_df[col].nunique() == 1:
        print(f'Columna {col} tiene un valor constante: {application_df[col].unique()[0]}')
        application_df = application_df.drop(columns=[col])
        print(f'Columna {col} eliminada.')
# Out:
# Columna FLAG_MOBIL tiene un valor constante: 1
# Columna FLAG_MOBIL eliminada.

# %% [markdown]
# ### 2.3. Normalización de las Variables

# %%
num_features = application_df.drop(['ID'], axis=1).select_dtypes(include=['int64', 'float64']).columns.tolist()
cat_features = application_df.select_dtypes(include=['object']).columns.tolist()

# %%
preprocessor = ColumnTransformer(transformers=[
    ('num', StandardScaler(), num_features),
    ('cat', OneHotEncoder(handle_unknown='ignore'), cat_features)
])

# %% [markdown]
# ### 2.4 Construcción de la Variable Objetivo

# %% [markdown]
# La variable objetivo se construirá a partir del historial de crédito. Se considerará que un cliente es "bueno" si no tiene retrasos significativos en sus pagos (por ejemplo, no más de dos meses de mora), y "malo" si tiene un historial negativo recurrente. Esto permitirá clasificar a los solicitantes en dos categorías: buenos clientes y malos clientes.

# %%
# Reemplazar los estados X y C por 0
credit_record_df['STATUS'] = credit_record_df['STATUS'].replace({'X': 0, 'C': 0})

def classify_client(status_list, status=2):
    """
    Clasifica a un cliente como "bueno" o "malo" basado en su historial de crédito.
    Args:
        status_list (list): Lista de estados de crédito del cliente. Ejemplo: [0, 1, 2, 3], donde, cada número representa un estado de crédito para un cliente en un mes específico.
        status (int): Estado de crédito considerado como "bueno" (por defecto 2).
    Returns:
        int: 1 si el cliente tiene todos los estados de crédito "buenos" (status), 0 si tiene al menos un estado de crédito "malo" (cualquier otro estado).
    """
    # Convertir los estados a enteros
    status_list = [int(s) for s in status_list]

    if all(s <= status for s in status_list):
        return 1 # Cliente "bueno"
    else:
        return 0 # Cliente "malo"

def build_target_variable(credit_record_df, status=2):
    """
    Construye la variable objetivo a partir del historial de crédito.
    Args:
        credit_record_df (DataFrame): DataFrame con el historial de crédito.
        status (int): Estado de crédito considerado como "bueno" (por defecto 2).
    Returns:
        Series: Serie con la variable objetivo, donde 1 indica un cliente "bueno" y 0 un cliente "malo".
    """
    target = credit_record_df.groupby('ID')['STATUS'].apply(list).reset_index()
    target['SCORE'] = target['STATUS'].apply(lambda x: classify_client(x, status))
    target = target[['ID', 'SCORE']]
    return target

def merge_data(application_df, target_df):
    """
    Combina el DataFrame de solicitudes con la variable objetivo.
    Args:
        application_df (DataFrame): DataFrame con las solicitudes.
        target_df (DataFrame): DataFrame con la variable objetivo.
    Returns:
        DataFrame: DataFrame combinado con las solicitudes y la variable objetivo.
    """
    merged_df = application_df.merge(target_df, on='ID', how='inner')
    return merged_df

# %% [markdown]
# ## 3. Estado del Arte

# %% [markdown]
# Para abordar el problema de predicción de aprobación de tarjetas de crédito, se analizó el artículo titulado “Predicting Credit Card Approval Using Machine Learning Techniques” de Ehsan Lotfi (2024) 1, publicado en la revista International Journal of Applied Data Science in Engineering and Health. En este artículo se aborda el problema de aprobación de tarjetas de crédito empleando el mismo dataset usado para este estudio.
#
# La variable objetivo en este estudio, que busca predecir la aprobación de tarjetas de crédito, es de naturaleza binaria (aprobado o rechazado) y presenta un desbalance significativo en sus clases. Su construcción se basa fundamentalmente en el historial crediticio del solicitante, extraído del conjunto de datos credit_record.csv, donde el campo STATUS es crucial al proporcionar información detallada sobre el estado del crédito y el comportamiento de pago, permitiendo así definir el resultado de la aprobación; sin embargo, no se confirma cuál es el umbral final elegido para la construcción de la variable.
#
# En cuanto al paradigma de aprendizaje, se utiliza el enfoque de aprendizaje supervisado, ya que el modelo se entrena con ejemplos etiquetados que indican si la solicitud de tarjeta fue aprobada o no. Para resolver el problema, los autores comparan cuatro algoritmos de aprendizaje automático: Regresión Logística, Árbol de Decisión, Random Forest y XGBoost (Extreme Gradient Boosting), cada uno con diferentes niveles de complejidad, capacidad de generalización e interpretación.
#
# La metodología de validación consiste en una partición del dataset en 80% para entrenamiento y 20% para prueba. Además, se utilizaron técnicas de validación cruzada y búsqueda aleatoria (Random Search) para el ajuste de hiperparámetros del modelo XGBoost, optimizando variables como la tasa de aprendizaje, la profundidad máxima del árbol, el número de estimadores y las penalizaciones L1 y L2.
#
# Respecto a las métricas de evaluación, se emplearon accuracy (exactitud), precision (precisión), recall (sensibilidad), F1-score (media armónica entre precisión y recall) y la matriz de confusión. Estas métricas permiten analizar no solo cuántas predicciones fueron correctas, sino también la calidad de las predicciones positivas, lo cual es clave en contextos donde hay desbalance de clases.
#
# Los resultados mostraron que el modelo XGBoost fue el más efectivo, alcanzando un 99.04% de exactitud, 85% de recall y 78% de precisión sobre el conjunto de prueba. Estos valores evidencian su capacidad para identificar correctamente a los solicitantes aprobados y minimizar errores tipo I y II. El artículo concluye que los métodos de ensamble avanzados como XGBoost y Random Forest superan claramente a modelos más simples como la regresión logística, particularmente cuando se trata de capturar relaciones no lineales y patrones complejos en grandes volúmenes de datos.
#
# Después de esto se realizó el análisis de un segundo artículo de Chang et al. (2024), titulado “Credit Risk Prediction Using Machine Learning and Deep Learning: A Study on Credit Card Customers” 2, el cual aborda el problema utilizando el mismo dataset.
#
# El criterio de “buen” y “mal” cliente, definido por la mora de la deuda de 60 días o más, es la base fundamental para la construcción de la variable objetivo. Dicha clasificación establece directamente si un solicitante es aprobado o rechazado, siendo un indicador cuantificable y determinante para la definición de la variable.
#
# El trabajo utiliza aprendizaje supervisado, ya que se entrena un modelo para predecir si un cliente será “bueno” o “malo” (es decir, si tendrá o no problemas de pago) a partir de datos históricos etiquetados. En este caso se probaron seis algoritmos de clasificación: regresión logística, Random Forest, redes neuronales (ANN), AdaBoost, LightGBM y XGBoost.
#
# El conjunto de datos se dividió en un 70% para entrenamiento y 30% para prueba. Se utilizó la técnica SMOTE (Synthetic Minority Oversampling Technique) para abordar el fuerte desbalance de clases, ya que solo el 1.3% de los clientes eran “malos”. Aunque no se aplicó validación cruzada (K-fold), se recomienda como trabajo futuro.
#
# Las métricas utilizadas fueron accuracy, precision, recall, F1-score, ROC-AUC y MCC (Matthews Correlation Coefficient). Esta última es útil para problemas con clases desbalanceadas, ya que considera todos los valores de la matriz de confusión. Un MCC de 1 indica una clasificación perfecta.
#
# Como resultado se obtuvo que el modelo XGBoost fue el más preciso, con un accuracy del 99.3%, precision y recall de 0.993, F1-score de 0.993, AUC de 0.997 y MCC de 0.986. LightGBM obtuvo resultados similares. Las redes neuronales, en cambio, tuvieron un rendimiento inferior debido al desbalance de clases.
#
# Como tercera referencia se analizó el artículo de Caggiano y Giardini (2024) [^3], titulado “Machine Learning Analysis of Credit Card Approval”, el cual aborda la problemática de la aprobación de tarjetas de crédito desde una perspectiva bancaria, donde identificar clientes “buenos” o “malos” representa una decisión crítica.
#
# El estudio emplea técnicas de Machine Learning para predecir qué usuarios podrían representar una mala inversión para el banco, basándose en información socioeconómica y en el comportamiento histórico de pago. Los autores resaltan que, ante el creciente uso de tarjetas de crédito, las entidades financieras necesitan modelos automatizados más precisos que superen las limitaciones del simple score crediticio tradicional.
#
# Para construir la variable objetivo, el estudio utilizó dos conjuntos de datos provenientes de Kaggle: uno con información demográfica y económica de los solicitantes, y otro con el historial mensual de pagos de sus tarjetas. Se etiquetó cada mes como “malo” si hubo mora superior a 30 días, y luego se calculó el porcentaje de meses en mora por tarjeta. Si ese porcentaje superaba el 10%, se consideraba una tarjeta “mala”. Luego, se agrupó la información por cliente y se definió como “cliente malo” a quien tuviera más del 15% de sus tarjetas en estado “malo”. Esta variable binaria (“bueno” o “malo”) fue utilizada como objetivo en los modelos de clasificación, aplicando algoritmos como regresión logística, Random Forest, Naive Bayes, MLP y Naive Bayes Tree, junto con técnicas como SMOTE y aprendizaje sensible al costo para mitigar el fuerte desbalance de clases.
#
# Por último, se examinó el artículo de Wang (2023), titulado “Credit Card Default Prediction with Data Modeling” [^4], el cual aborda la problemática del riesgo crediticio mediante la predicción de incumplimientos en el pago de tarjetas de crédito. Utilizando un conjunto de datos de Kaggle, compuesto por información demográfica, económica y comportamental de los solicitantes, el estudio propone la implementación de modelos de aprendizaje automático para anticipar qué clientes podrían representar una amenaza financiera para las entidades emisoras.
#
# Se evaluaron cuatro algoritmos: regresión logística, KNN, Random Forest y XGBoost, utilizando métricas como AUC, F1-score, precisión y recall. El objetivo principal fue minimizar las pérdidas bancarias derivadas de la aprobación errónea de clientes con alto riesgo de incumplimiento, estableciendo que Random Forest y XGBoost fueron los más eficaces, alcanzando un AUC de 0.771 y 0.753 respectivamente.
#
# La variable objetivo fue construida a partir del historial de pagos mensuales de cada cliente, clasificado originalmente en ocho niveles que indicaban el estado de cumplimiento de la deuda. Se redefinió como una variable binaria: los valores “0”, “C” y “X” (pagado a tiempo o sin préstamo activo) se agruparon como clase negativa (clientes buenos), mientras que cualquier estado de mora superior a 30 días fue asignado como clase positiva (clientes malos). Esta simplificación permitió evaluar el desempeño de los modelos en la detección de clientes con mayor probabilidad de incumplimiento, enfrentando el reto de un conjunto de datos desbalanceado donde la mayoría de usuarios cumplía con sus pagos. Para mitigar este problema, los autores exploraron ajustes en el umbral de clasificación y validación cruzada para optimizar el rendimiento predictivo de los modelos.

# %% [markdown]
# ## 4. Entrenamiento y Evaluación de los Modelos

# %% [markdown]
# ### 4.1. Configuración Experimental

# %%
# Gráfico de la fuente de la variable objetivo
plt.figure(figsize=(10, 6))
sns.countplot(x='STATUS', data=credit_record_df)
plt.title('Distribución de Estados de Crédito')
plt.xlabel('Estado de Crédito')
plt.ylabel('Número de Clientes')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - **Estrategía de Validación**: Se utilizará validación cruzada estratificada para asegurar que cada fold tenga una representación adecuada de las clases.
#
# - **Estrategía de Sobremuestreo**: Debido a que el dataset presenta un desbalance significativo entre las clases de buenos y malos clientes, se aplicará la técnica de sobremuestreo SMOTE (Synthetic Minority Over-sampling Technique) para equilibrar las clases. Esta técnica genera ejemplos sintéticos de la clase minoritaria, lo que ayuda a mejorar el rendimiento del modelo en la predicción de la clase menos representada.
#
# - **Métricas de Evaluación**: Se utilizarán métricas como la precisión, recall, F1-score y AUC-ROC para evaluar el rendimiento de los modelos. Estas métricas son especialmente importantes en problemas de clasificación desbalanceada, ya que proporcionan una visión más completa del desempeño del modelo.
#
# **Modelos a Evaluar**
#
# - **(Modelo Párametrico) Regresión Logística**:
#
# ```
# "max_iter": [100, 200]
# "solver": ["liblinear", "saga"]
# "C": [0.01, 0.1, 1, 10]
# "penalty": ["l1", "l2"]
# ```
#
# - **(Modelo No Párametrico) K-Nearest Neighbors**:
#
# ```
# "n_neighbors": [3, 5, 7, 9]
# "weights": ["uniform", "distance"]
# "metric": ["euclidean", "manhattan"]
# ```
#
# - **(Modelo Basado en el Ensamble de Árboles) XGBoost**:
#
# ```
# "n_estimators": [50, 100, 200]
# "max_depth": [3, 6, 9]
# "learning_rate": [0.01, 0.1, 0.2]
# ```
#
# - **(Red Neuronal) MLPClassifier**:
#
# ```
# "hidden_layer_sizes": [(50,), (100,), (50, 50)]
# "activation": ["relu", "tanh"]
# "solver": ["adam", "sgd"]
# "alpha": [0.0001, 0.001]
# "learning_rate_init": [0.001, 0.01]
# "max_iter": [200]
# ```
#
# - **(Máquina de Vectores de Soporte) SVC**:
#
# ```
# "C": [0.1, 1, 10]
# "kernel": ["linear", "rbf"]
# "gamma": ["scale", "auto"]
# ```

# %% [markdown]
# ### 4.2. Resultados del Entrenamiento de Modelos

# %%
TARGET_STATUS = 2  # Estado de crédito considerado como "bueno"
clasified_credit_record_df = build_target_variable(credit_record_df, TARGET_STATUS)
data = merge_data(application_df, clasified_credit_record_df)

data["SCORE"].value_counts()
# Out:
# SCORE
# 1    36155
# 0      302
# Name: count, dtype: int64

# %%
# Conjuntos de entrenamiento, validación y prueba
X = data.iloc[:, data.columns != 'SCORE']
y = data['SCORE']

# Train: 70%, Test: 30%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# Preprocesamiento de datos
X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# Sobre-muestreo de la clase minoritaria
oversample = SMOTE()
X_train, y_train = oversample.fit_resample(X_train, y_train)

# Validación cruzada estratificada
cv = StratifiedKFold(n_splits=2, shuffle=True, random_state=42)

# %%
X.shape, y.shape
# Out:
# ((36457, 17), (36457,))

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((50630, 54), (50630,), (10938, 54), (10938,))

# %%
def find_best_model(X_train, y_train, model, params, scoring="accuracy", n_jobs=-1):
    """
    Encuentra el mejor modelo para un conjunto de hiperparámetros dado.

    Evalua el modelo para cada combinación de hiperparámetros usando GridSearchCV.

    Args:
        X_train (array-like): Datos de entrenamiento.
        y_train (array-like): Etiquetas de entrenamiento.
        model (estimator): Modelo a evaluar.
        params (dict): Hiperparámetros a evaluar.
        scoring (str): Métrica de evaluación (por defecto 'accuracy').
        n_jobs (int): Número de trabajos a ejecutar en paralelo (por defecto -1, que usa todos los núcleos disponibles).
    Returns:
        best_model (estimator): El mejor modelo encontrado.
        best_params (dict): Los mejores hiperparámetros encontrados.
    """
    grid_search = GridSearchCV(model, params, scoring=scoring, cv=cv, n_jobs=n_jobs, verbose=1)

    print("Buscando el mejor modelo...")
    grid_search.fit(X_train, y_train)
    best_model = grid_search.best_estimator_
    best_params = grid_search.best_params_
    print(f"Mejor modelo: {best_model}")
    print(f"Mejores hiperparámetros: {best_params}")
    return best_model, best_params


def evaluate_model(model, X_train, y_train, X_test, y_test, splitter):
    """
    Evalúa el modelo en los conjuntos de entrenamiento y prueba.

    Args:
        model (estimator): Modelo a evaluar.
        X_train (array-like): Datos de entrenamiento.
        y_train (array-like): Etiquetas de entrenamiento.
        X_test (array-like): Datos de prueba.
        y_test (array-like): Etiquetas de prueba.
        splitter (StratifiedKFold): Estrategia de validación cruzada estratificada.
    Returns:
        dict: Resultados de la evaluación del modelo.
    """
    train_errors = []
    val_errors = []
    test_errors = []

    print("Evaluando el modelo...")
    for train_index, test_index in splitter.split(X_train, y_train):
        X_train_fold, X_val_fold = X_train[train_index], X_train[test_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[test_index]

        model.fit(X_train_fold, y_train_fold)
        y_pred = model.predict(X_val_fold)

        train_error = 1 - accuracy_score(y_train_fold, model.predict(X_train_fold))
        val_error = 1 - accuracy_score(y_val_fold, y_pred)
        test_error = 1 - accuracy_score(y_test, model.predict(X_test))
        train_errors.append(train_error)
        val_errors.append(val_error)
        test_errors.append(test_error)

    results = {
        "train_error": np.mean(train_errors),
        "std_train_error": np.std(train_errors),
        "val_error": np.mean(val_errors),
        "val_std_error": np.std(val_errors),
        "test_error": np.mean(test_errors),
        "std_test_error": np.std(test_errors),
        "classification_report": classification_report(y_test, model.predict(X_test)),
        "confusion_matrix": confusion_matrix(y_test, model.predict(X_test)),
        "roc_auc_score": roc_auc_score(y_test, model.predict_proba(X_test)[:, 1]),
        "roc_curve": roc_curve(y_test, model.predict_proba(X_test)[:, 1]),
    }

    return results


def plot_results(results):
    """
    Plotea los resultados de la evaluación del modelo.

    Args:
        results (dict): Resultados de la evaluación del modelo.
    """
    # Gráfico de errores de entrenamiento, validación y prueba
    plt.figure(figsize=(10, 6))
    sns.heatmap(results["confusion_matrix"], annot=True, fmt="d", cmap="Blues")
    plt.title("Matriz de Confusión")
    plt.xlabel("Predicción")
    plt.ylabel("Valor Esperado")
    plt.show()

    # Reporte de clasificación
    print("Reporte de Clasificación:")
    print(results["classification_report"])

    # Curva ROC
    fpr, tpr, _ = results["roc_curve"]
    plt.figure(figsize=(10, 6))
    plt.plot(fpr, tpr, color="blue", label="ROC Curve")
    plt.plot([0, 1], [0, 1], color="red", linestyle="--", label="Random Guess")
    plt.title("Curva ROC")
    plt.xlabel("Tasa de Falsos Positivos")
    plt.ylabel("Tasa de Verdaderos Positivos")
    plt.legend()
    plt.show()

    # Imprimir errores con sus intervalos de confianza
    print(
        f"Error de Entrenamiento: {results['train_error']:.4f} ± {results['std_train_error']:.4f}"
    )
    print(
        f"Error de Validación: {results['val_error']:.4f} ± {results['val_std_error']:.4f}"
    )
    print(
        f"Error de Prueba: {results['test_error']:.4f} ± {results['std_test_error']:.4f}"
    )

# %% [markdown]
# #### 4.2.1. Regresión Logística

# %%
# Hiperparámetros usados
lr_params = {
    "max_iter": [100, 200],
    "solver": ["liblinear", "saga"],
    "C": [0.01, 0.1, 1, 10],
    "penalty": ["l1", "l2"],
}

# Modelo base de regresión logística
lr_model = LogisticRegression(random_state=42)

best_lr_model, best_lr_params = find_best_model(X_train, y_train, lr_model, lr_params)

lr_results = evaluate_model(best_lr_model, X_train, y_train, X_test, y_test, cv)

plot_results(lr_results)
# Out:
# Buscando el mejor modelo...
# Fitting 2 folds for each of 32 candidates, totalling 64 fits
# d:\UdeA\Semestre IX\Modelos y Simulación II\proyecto\.venv\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Mejor modelo: LogisticRegression(C=1, random_state=42, solver='saga')
# Mejores hiperparámetros: {'C': 1, 'max_iter': 100, 'penalty': 'l2', 'solver': 'saga'}
# Evaluando el modelo...
# d:\UdeA\Semestre IX\Modelos y Simulación II\proyecto\.venv\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# d:\UdeA\Semestre IX\Modelos y Simulación II\proyecto\.venv\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Reporte de Clasificación:
# ...

# %% [markdown]
# #### 4.2.2. KNN (K-Nearest Neighbors)

# %%
# Hiperparámetros usados
knn_params = {
    "n_neighbors": [3, 5, 7, 9],
    "weights": ["distance"],
    "metric": ["euclidean", "manhattan"],
}

# Modelo base de KNN
knn_model = KNeighborsClassifier()

best_knn_model, best_lr_params = find_best_model(X_train, y_train, knn_model, knn_params)

knn_results = evaluate_model(best_knn_model, X_train, y_train, X_test, y_test, cv)

plot_results(knn_results)
# Out:
# Buscando el mejor modelo...
# Fitting 2 folds for each of 8 candidates, totalling 16 fits
# Mejor modelo: KNeighborsClassifier(metric='manhattan', n_neighbors=9, weights='distance')
# Mejores hiperparámetros: {'metric': 'manhattan', 'n_neighbors': 9, 'weights': 'distance'}
# Evaluando el modelo...
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.34      0.16      0.22       108
#            1       0.99      1.00      0.99     10830
#
#     accuracy                           0.99     10938
#    macro avg       0.67      0.58      0.60     10938
# weighted avg       0.99      0.99      0.99     10938
# Error de Entrenamiento: 0.0015 ± 0.0001
# Error de Validación: 0.0046 ± 0.0007
# Error de Prueba: 0.0110 ± 0.0004

# %% [markdown]
# #### 4.2.3. XGBoost (eXtreme Gradient Boosting)

# %%
# Hiperparámetros usados
xgb_params = {
    "n_estimators": [50, 100, 200],
    "max_depth": [3, 6, 9],
    "learning_rate": [0.01, 0.1, 0.2],
}


# Modelo base de XGBoost
xgb_model = XGBClassifier()

best_xgb_model, best_xgb_params = find_best_model(X_train, y_train, xgb_model, xgb_params)

xgb_results = evaluate_model(best_xgb_model, X_train, y_train, X_test, y_test, cv)

plot_results(xgb_results)
# Out:
# Buscando el mejor modelo...
# Fitting 2 folds for each of 27 candidates, totalling 54 fits
# Mejor modelo: XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.2, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=9,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=None, num_parallel_tree=None, ...)
# Mejores hiperparámetros: {'learning_rate': 0.2, 'max_depth': 9, 'n_estimators': 200}
# Evaluando el modelo...
# ...

# %% [markdown]
# #### 4.2.4. MLPClassifier (Red Neuronal Perceptrón Multicapa)

# %%
mlp_params = {
    "hidden_layer_sizes": [(50,), (100,), (50, 50)],
    "activation": ["relu", "tanh"],
    "solver": ["adam", "sgd"],
    "alpha": [0.0001, 0.001],
    "learning_rate_init": [0.001, 0.01],
    "max_iter": [200]
}


# Modelo base de MLPClassifier
mlp_model = MLPClassifier(random_state=42)

best_mlp_model, best_mlp_params = find_best_model(X_train, y_train, mlp_model, mlp_params)

mlp_results = evaluate_model(best_mlp_model, X_train, y_train, X_test, y_test, cv)

plot_results(mlp_results)
# Out:
# Buscando el mejor modelo...
# Fitting 2 folds for each of 48 candidates, totalling 96 fits
# Mejor modelo: MLPClassifier(hidden_layer_sizes=(50, 50), learning_rate_init=0.01,
#               random_state=42)
# Mejores hiperparámetros: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate_init': 0.01, 'max_iter': 200, 'solver': 'adam'}
# Evaluando el modelo...
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.12      0.36      0.19        99
#            1       0.99      0.98      0.99     10839
#
#     accuracy                           0.97     10938
#    macro avg       0.56      0.67      0.59     10938
# weighted avg       0.99      0.97      0.98     10938
# Error de Entrenamiento: 0.0092 ± 0.0000
# Error de Validación: 0.0126 ± 0.0007
# Error de Prueba: 0.0276 ± 0.0013

# %% [markdown]
# #### 4.2.5. SVM (Máquina de Vectores de Soporte)

# %%
# Hiperparámetros usados
svm_params = {
    "C": [0.1, 1, 10],
    "kernel": ["linear", "rbf"],
    "gamma": ["scale", "auto"]
}

# Modelo base de SVM
svm_model = SVC(probability=True)

best_svm_model, best_svm_params = find_best_model(
    X_train, y_train, svm_model, svm_params, n_jobs=8
)

svm_results = evaluate_model(best_svm_model, X_train, y_train, X_test, y_test, cv)

plot_results(svm_results)
# Out:
# Buscando el mejor modelo...
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Mejor modelo: SVC(C=10, probability=True)
# Mejores hiperparámetros: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# Evaluando el modelo...
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.08      0.35      0.13        99
#            1       0.99      0.96      0.98     10839
#
#     accuracy                           0.96     10938
#    macro avg       0.54      0.66      0.55     10938
# weighted avg       0.99      0.96      0.97     10938
# Error de Entrenamiento: 0.0239 ± 0.0018
# Error de Validación: 0.0268 ± 0.0005
# Error de Prueba: 0.0462 ± 0.0022

# %% [markdown]
# ## 5. Reducción de Dimensión

# %% [markdown]
# ### 5.1. Selección de Características

# %%
feature_names = preprocessor.get_feature_names_out()

# %%
from sklearn.feature_selection import f_classif
import pandas as pd

f_scores, p_values = f_classif(X_train, y_train)

f_df = pd.DataFrame({
    'Feature': feature_names,
    'F-score': f_scores,
    'p-value': p_values
}).sort_values(by='F-score', ascending=False)

f_df.head(10)  # Muestra las 10 más útiles
# Out:
#                                        Feature      F-score        p-value
# 24      cat__NAME_FAMILY_STATUS_Civil marriage  1232.174937  1.004686e-266
# 38             cat__OCCUPATION_TYPE_Core staff   562.040656  1.430681e-123
# 16         cat__NAME_INCOME_TYPE_State servant   422.865018   1.402776e-93
# 15             cat__NAME_INCOME_TYPE_Pensioner   338.348635   2.572547e-75
# 35            cat__OCCUPATION_TYPE_Accountants   333.084096   3.543040e-74
# 50            cat__OCCUPATION_TYPE_Sales staff   277.211264   4.453465e-62
# 31  cat__NAME_HOUSING_TYPE_Municipal apartment   269.385348   2.213557e-60
# 8                           cat__CODE_GENDER_F   266.507595   9.311073e-60
# 9                           cat__CODE_GENDER_M   266.507595   9.311073e-60
# 48  cat__OCCUPATION_TYPE_Private service staff   242.287446   1.669054e-54

# %%
f_df.tail(10)  # Muestra las 10 menos útiles
# Out:
#                                       Feature    F-score   p-value
# 1                       num__AMT_INCOME_TOTAL  13.834855  0.000200
# 25            cat__NAME_FAMILY_STATUS_Married   8.458333  0.003635
# 17              cat__NAME_INCOME_TYPE_Student   7.001659  0.008146
# 20  cat__NAME_EDUCATION_TYPE_Higher education   6.805994  0.009088
# 40               cat__OCCUPATION_TYPE_Drivers   6.217079  0.012656
# 37         cat__OCCUPATION_TYPE_Cooking staff   2.686933  0.101181
# 53  cat__OCCUPATION_TYPE_Waiters/barmen staff   2.622590  0.105359
# 30   cat__NAME_HOUSING_TYPE_House / apartment   1.685663  0.194180
# 4                        num__FLAG_WORK_PHONE   1.115112  0.290978
# 44              cat__OCCUPATION_TYPE_Laborers   1.048991  0.305745

# %%
mi_scores = mutual_info_classif(X_train, y_train)

mi_df = pd.DataFrame({
    'Feature': feature_names,
    'MI Score': mi_scores
}).sort_values(by='MI Score', ascending=False)

mi_df.head(10)
# Out:
# d:\UdeA\Semestre IX\Modelos y Simulación II\proyecto\.venv\Lib\site-packages\sklearn\metrics\cluster\_supervised.py:59: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and binary values for target
#   warnings.warn(msg, UserWarning)
# d:\UdeA\Semestre IX\Modelos y Simulación II\proyecto\.venv\Lib\site-packages\sklearn\metrics\cluster\_supervised.py:59: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and binary values for target
#   warnings.warn(msg, UserWarning)
# d:\UdeA\Semestre IX\Modelos y Simulación II\proyecto\.venv\Lib\site-packages\sklearn\metrics\cluster\_supervised.py:59: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and binary values for target
#   warnings.warn(msg, UserWarning)
# ...

# %%
mi_df.tail(10)
# Out:
#                                        Feature  MI Score
# 51            cat__OCCUPATION_TYPE_Secretaries  0.006109
# 45     cat__OCCUPATION_TYPE_Low-skill Laborers  0.005797
# 53   cat__OCCUPATION_TYPE_Waiters/barmen staff  0.004997
# 43               cat__OCCUPATION_TYPE_IT staff  0.004174
# 48  cat__OCCUPATION_TYPE_Private service staff  0.003297
# 6                              num__FLAG_EMAIL  0.001813
# 49          cat__OCCUPATION_TYPE_Realty agents  0.000795
# 41               cat__OCCUPATION_TYPE_HR staff  0.000767
# 19    cat__NAME_EDUCATION_TYPE_Academic degree  0.000233
# 17               cat__NAME_INCOME_TYPE_Student  0.000096

# %%
# Solo variables numéricas sin codificar
num_features_data = data[num_features]

plt.figure(figsize=(10, 8))
sns.heatmap(num_features_data.corr(), annot=True, cmap='coolwarm')
plt.title('Matriz de correlación entre variables numéricas')
plt.show()

# %%
sfs_xgb = SequentialFeatureSelector(
    best_xgb_model,
    direction="forward",
    scoring="f1",
    cv=cv,
    n_jobs=-1
)

sfs_xgb.fit(X_train, y_train)

# Datos transformados
X_train_xgb_sel = sfs_xgb.transform(X_train)
X_test_xgb_sel = sfs_xgb.transform(X_test)

# %%
xgb_results_sfs = evaluate_model(best_xgb_model, X_train_xgb_sel, y_train, X_test_xgb_sel, y_test, cv)
plot_results(xgb_results_sfs)
# Out:
# Evaluando el modelo...
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.29      0.27      0.28        99
#            1       0.99      0.99      0.99     10839
#
#     accuracy                           0.99     10938
#    macro avg       0.64      0.63      0.64     10938
# weighted avg       0.99      0.99      0.99     10938
# Error de Entrenamiento: 0.0025 ± 0.0001
# Error de Validación: 0.0053 ± 0.0001
# Error de Prueba: 0.0123 ± 0.0004

# %%
sfs_mlp = SequentialFeatureSelector(
    best_mlp_model,
    direction="forward",
    scoring="f1",
    cv=cv,
    n_jobs=-1
)

sfs_mlp.fit(X_train, y_train)

# Datos transformados
X_train_mlp_sel = sfs_mlp.transform(X_train)
X_test_mlp_sel = sfs_mlp.transform(X_test)
# Out:
# d:\UdeA\Semestre IX\Modelos y Simulación II\proyecto\.venv\Lib\site-packages\joblib\externals\loky\process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(

# %%
mlp_results_sfs = evaluate_model(best_mlp_model, X_train_mlp_sel, y_train, X_test_mlp_sel, y_test, cv)
plot_results(mlp_results_sfs)
# Out:
# Evaluando el modelo...
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.12      0.40      0.19        99
#            1       0.99      0.97      0.98     10839
#
#     accuracy                           0.97     10938
#    macro avg       0.56      0.69      0.59     10938
# weighted avg       0.99      0.97      0.98     10938
# Error de Entrenamiento: 0.0106 ± 0.0008
# Error de Validación: 0.0136 ± 0.0018
# Error de Prueba: 0.0292 ± 0.0026

# %%
print("Reducción de características XGBoost:",
      (1 - X_train_xgb_sel.shape[1] / X_train.shape[1]) * 100, "%")

print("Reducción de características MLP:",
      (1 - X_train_mlp_sel.shape[1] / X_train.shape[1]) * 100, "%")
# Out:
# Reducción de características XGBoost: 50.0 %
# Reducción de características MLP: 50.0 %

# %% [markdown]
# ### 5.2. Extracción de Características

# %%
# Convertir sparse matrices a densas para usar PCA
X_train_dense = X_train.toarray()
X_test_dense = X_test.toarray()

# %%
# PCA reteniendo el 95% de la varianza
pca = PCA(n_components=0.95)
X_train_pca = pca.fit_transform(X_train_dense)
X_test_pca = pca.transform(X_test_dense)

print(f"Número de componentes seleccionados: {pca.n_components_}")
# Out:
# Número de componentes seleccionados: 18

# %%
xgb_results_pca = evaluate_model(best_xgb_model, X_train_pca, y_train, X_test_pca, y_test, cv)
plot_results(xgb_results_pca)
# Out:
# Evaluando el modelo...
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.21      0.35      0.26        99
#            1       0.99      0.99      0.99     10839
#
#     accuracy                           0.98     10938
#    macro avg       0.60      0.67      0.63     10938
# weighted avg       0.99      0.98      0.98     10938
# Error de Entrenamiento: 0.0024 ± 0.0000
# Error de Validación: 0.0073 ± 0.0000
# Error de Prueba: 0.0176 ± 0.0004

# %%
mlp_results_pca = evaluate_model(best_mlp_model, X_train_pca, y_train, X_test_pca, y_test, cv)
plot_results(mlp_results_pca)
# Out:
# Evaluando el modelo...
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.15      0.40      0.22        99
#            1       0.99      0.98      0.99     10839
#
#     accuracy                           0.97     10938
#    macro avg       0.57      0.69      0.60     10938
# weighted avg       0.99      0.97      0.98     10938
# Error de Entrenamiento: 0.0093 ± 0.0004
# Error de Validación: 0.0123 ± 0.0008
# Error de Prueba: 0.0260 ± 0.0002

# %%
mlp_results_pca = evaluate_model(best_mlp_model, X_train_pca, y_train, X_test_pca, y_test, cv)
plot_results(mlp_results_pca)
# Out:
# Evaluando el modelo...
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.15      0.40      0.22        99
#            1       0.99      0.98      0.99     10839
#
#     accuracy                           0.97     10938
#    macro avg       0.57      0.69      0.60     10938
# weighted avg       0.99      0.97      0.98     10938
# Error de Entrenamiento: 0.0093 ± 0.0004
# Error de Validación: 0.0123 ± 0.0008
# Error de Prueba: 0.0260 ± 0.0002

# %%
original_features = X_train_dense.shape[1]
reduced_features = pca.n_components_
reduction_percentage = (1 - reduced_features / original_features) * 100

print(f"Reducción de características: {reduction_percentage:.2f}%")
# Out:
# Reducción de características: 66.67%

# %% [markdown]
# ### Referencias
#
# [^1]: Lotfi, E. (2024). Predicting Credit Card Approval Using Machine Learning Techniques. International Journal of Applied Data Science in Engineering and Health.
#
# [^2]: Chang et al. (2024). Credit Risk Prediction Using Machine Learning and Deep Learning: A Study on Credit Card Customers.
#
# [^3]: Caggiano, G., & Giardini, L. (2024). Machine Learning Analysis of Credit Card Approval.
#
# [^4]: Wang, Y. (2023). Credit Card Default Prediction with Data Modeling.
